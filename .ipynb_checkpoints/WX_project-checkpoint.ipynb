# %%
north, south, east, west = 31.6180, 31.5212, 120.3523, 120.2443

# %%
import osmnx as ox, geopandas as gpd

# %%
ox.config(log_file=True, log_console=True, use_cache=True)

# %%
G1 = ox.graph_from_bbox(north, south, east, west, network_type='drive_service')

# %%
G1 = ox.project_graph(G1)

# %%
fig, ax = ox.plot_graph(G1)

# %%
ox.save_graph_shapefile(G1, filename='WX_ring')

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/left/python基础教程'

# %%
exit()

# %%
import os
os.getcwd()
# Out:
# '/Users/left/WXRd'

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('data/WX_ring/major_edges.csv')

# %%
df1.head(3)
# Out:
#    OBJECTID access bridge       from_  highway  key lanes      length  \
# 0         1                 313736000  primary    0         81.528535
# 1         2                2530789759  primary    0        327.176053
# 2         3                 313736002  primary    0     2  104.466123
#
#   maxspeed name  oneway      osmid ref          to tunnel  Shape_Length
# 0           兴源路    True  147866731      2530789764            81.605676
# 1           兴源路    True  147866731       313736000           327.562185
# 2           春申路    True  147866737      3053008326           104.415531

# %%
df2 = df1[df1['oneway']=='True']
# Out:
# /Users/left/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a101a143f446> in <module>()
# ----> 1 df2 = df1[df1['oneway']=='True']
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     816                     result = getattr(x, name)(y)
# ...

# %%
df1['oneway']
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
# 5        True
# 6        True
# 7        True
# 8       False
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21      False
# 22       True
# 23       True
# 24       True
# 25       True
# 26      False
# 27       True
# 28      False
# 29      False
#         ...
# 1492     True
# 1493     True
# 1494     True
# 1495     True
# 1496     True
# 1497     True
# 1498     True
# 1499     True
# 1500     True
# 1501     True
# 1502     True
# 1503     True
# 1504     True
# 1505     True
# 1506     True
# 1507     True
# 1508     True
# 1509     True
# 1510     True
# 1511     True
# 1512     True
# 1513     True
# 1514     True
# 1515     True
# 1516     True
# 1517     True
# 1518     True
# 1519     True
# 1520     True
# 1521     True
# ...

# %%
df1['oneway'] =='True'
# Out:
# /Users/left/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c29eb9d97dd2> in <module>()
# ----> 1 df1['oneway'] =='True'
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#     816                     result = getattr(x, name)(y)
#     817                 if result is NotImplemented:
# ...

# %%
df1['oneway'] == True
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
# 5        True
# 6        True
# 7        True
# 8       False
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21      False
# 22       True
# 23       True
# 24       True
# 25       True
# 26      False
# 27       True
# 28      False
# 29      False
#         ...
# 1492     True
# 1493     True
# 1494     True
# 1495     True
# 1496     True
# 1497     True
# 1498     True
# 1499     True
# 1500     True
# 1501     True
# 1502     True
# 1503     True
# 1504     True
# 1505     True
# 1506     True
# 1507     True
# 1508     True
# 1509     True
# 1510     True
# 1511     True
# 1512     True
# 1513     True
# 1514     True
# 1515     True
# 1516     True
# 1517     True
# 1518     True
# 1519     True
# 1520     True
# 1521     True
# ...

# %%
df2 = df1[df1['oneway']==True]

# %%
df2.describe()
# Out:
#           OBJECTID         from_         key       length            to  \
# count   941.000000  9.410000e+02  941.000000   941.000000  9.410000e+02
# mean   1002.226355  2.456996e+09    0.002125   308.132080  2.437058e+09
# std     606.179621  1.070252e+09    0.046078   405.289735  1.075818e+09
# min       1.000000  3.137360e+08    0.000000     1.031263  3.137360e+08
# 25%     513.000000  1.765779e+09    0.000000    64.669695  1.765779e+09
# 50%     841.000000  2.313840e+09    0.000000   185.254281  2.313831e+09
# 75%    1516.000000  3.017317e+09    0.000000   400.475662  2.933917e+09
# max    2025.000000  5.245323e+09    1.000000  4569.915146  5.245323e+09
#
#        Shape_Length
# count    941.000000
# mean     308.131229
# std      405.355040
# min        1.026217
# 25%       64.818041
# 50%      185.240248
# 75%      399.618493
# max     4576.004543

# %%
df2.head(2)
# Out:
#    OBJECTID access bridge       from_  highway  key lanes      length  \
# 0         1                 313736000  primary    0         81.528535
# 1         2                2530789759  primary    0        327.176053
#
#   maxspeed name  oneway      osmid ref          to tunnel  Shape_Length
# 0           兴源路    True  147866731      2530789764            81.605676
# 1           兴源路    True  147866731       313736000           327.562185

# %%
for i in df2:
    print(i)
# Out:
# OBJECTID
# access
# bridge
# from_
# highway
# key
# lanes
# length
# maxspeed
# name
# oneway
# osmid
# ref
# to
# tunnel
# Shape_Length

# %%
df2.loc[2]
# Out:
# OBJECTID                 3
# access
# bridge
# from_            313736002
# highway            primary
# key                      0
# lanes                    2
# length             104.466
# maxspeed
# name                   春申路
# oneway                True
# osmid            147866737
# ref
# to              3053008326
# tunnel
# Shape_Length       104.416
# Name: 2, dtype: object

# %%
df2.iloc[2]['tunnel']
# Out:
# ' '

# %%
df2.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c822c71ba45e> in <module>()
# ----> 1 df2.index()
#
# TypeError: 'Int64Index' object is not callable

# %%
df3 = pd.read_csv('data/WX_ring/major_nodes.csv')

# %%
df3.head(1)
# Out:
#    OBJECTID highway        lat         lon      osmid
# 0         1          31.588591  120.298825  313736000

# %%
osmid_dict = dict(zip(df3['osmid'],df3['lat','lon']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('lat', 'lon')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-00050636db19> in <module>()
# ...

# %%
df3['lat','lon']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('lat', 'lon')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-e8b2a5addb61> in <module>()
# ----> 1 df3['lat','lon']
#
# ...

# %%
df3[['lat','lon']]
# Out:
#             lat         lon
# 0     31.588591  120.298825
# 1     31.592855  120.292434
# 2     31.589694  120.296890
# 3     31.580985  120.286356
# 4     31.542980  120.265614
# 5     31.543440  120.279381
# 6     31.547045  120.292515
# 7     31.566251  120.319722
# 8     31.566767  120.323186
# 9     31.586710  120.303146
# 10    31.582829  120.299529
# 11    31.580403  120.303760
# 12    31.577061  120.289333
# 13    31.554708  120.301846
# 14    31.572965  120.297902
# 15    31.568053  120.302834
# 16    31.574313  120.304203
# 17    31.573570  120.299717
# 18    31.576090  120.304839
# 19    31.576018  120.301974
# 20    31.575934  120.297784
# 21    31.606675  120.289686
# 22    31.598734  120.283447
# 23    31.567948  120.297562
# 24    31.572336  120.303617
# 25    31.577259  120.286705
# 26    31.579077  120.275012
# 27    31.567909  120.263270
# 28    31.561174  120.265034
# 29    31.581918  120.301811
# ...         ...         ...
# 1299  31.567908  120.322841
# ...

# %%
osmid_dict = dict(zip(df3['osmid'],df3[['lat','lon']]))

# %%
osmid_dict
# Out:
# {313736000: 'lat', 313736002: 'lon'}

# %%
df3['osmid']
# Out:
# 0        313736000
# 1        313736002
# 2        313736004
# 3        313736019
# 4        313736073
# 5        313736076
# 6        313736081
# 7        313736097
# 8        313736102
# 9        313736149
# 10       313736389
# 11       506565871
# 12       506565876
# 13       544367022
# 14       544367024
# 15       544367025
# 16       544367031
# 17       544367033
# 18       544367035
# 19       544367037
# 20       544367039
# 21       606775659
# 22       606775671
# 23       606778663
# 24       606778723
# 25       606790266
# 26       606790312
# 27       606790327
# 28       606790332
# 29       606791949
#            ...
# 1299    4226475380
# 1300    4226475500
# 1301    4226475501
# 1302    4226475502
# 1303    4226475510
# 1304    4226475515
# 1305    4226475516
# 1306    4226475520
# 1307    4226475522
# 1308    4226475526
# 1309    4226475528
# 1310    4226475534
# 1311    4226475538
# 1312    4226475539
# 1313    4763018953
# 1314    5168543893
# ...

# %%
type(df3['osmid'])
# Out:
# pandas.core.series.Series

# %%
osmid_dict = dict(zip(np.array(df3['osmid']),np.array(df3[['lat','lon']])))

# %%
osmid_dict
# Out:
# {313736000: array([ 31.5885914, 120.2988253]),
#  313736002: array([ 31.5928548, 120.2924345]),
#  313736004: array([ 31.5896944, 120.2968899]),
#  313736019: array([ 31.5809854, 120.2863562]),
#  313736073: array([ 31.5429805, 120.2656142]),
#  313736076: array([ 31.54344  , 120.2793812]),
#  313736081: array([ 31.5470452, 120.2925152]),
#  313736097: array([ 31.5662514, 120.3197217]),
#  313736102: array([ 31.5667673, 120.3231864]),
#  313736149: array([ 31.5867098, 120.3031459]),
#  313736389: array([ 31.5828291, 120.2995291]),
#  506565871: array([ 31.5804032, 120.3037599]),
#  506565876: array([ 31.5770613, 120.2893326]),
#  544367022: array([ 31.5547083, 120.3018459]),
#  544367024: array([ 31.5729648, 120.2979018]),
#  544367025: array([ 31.5680527, 120.3028344]),
#  544367031: array([ 31.5743128, 120.3042033]),
#  544367033: array([ 31.5735697, 120.2997173]),
#  544367035: array([ 31.5760901, 120.3048391]),
#  544367037: array([ 31.5760179, 120.3019744]),
# ...

# %%
osmid_dict = dict(zip(df3['osmid'],df3[['lat','lon']]))

# %%
osmid_dict
# Out:
# {313736000: 'lat', 313736002: 'lon'}

# %%
osmid_lat_key = dict(zip(df3['osmid'],df3['lat']))

# %%
osmid_lat_key
# Out:
# {313736000: 31.5885914,
#  313736002: 31.5928548,
#  313736004: 31.589694399999996,
#  313736019: 31.5809854,
#  313736073: 31.5429805,
#  313736076: 31.543440000000004,
#  313736081: 31.5470452,
#  313736097: 31.566251399999995,
#  313736102: 31.566767300000002,
#  313736149: 31.5867098,
#  313736389: 31.5828291,
#  506565871: 31.5804032,
#  506565876: 31.5770613,
#  544367022: 31.554708299999998,
#  544367024: 31.572964799999998,
#  544367025: 31.5680527,
#  544367031: 31.5743128,
#  544367033: 31.5735697,
#  544367035: 31.576090100000002,
#  544367037: 31.5760179,
#  544367039: 31.575933600000003,
#  606775659: 31.6066748,
#  606775671: 31.598734499999996,
#  606778663: 31.567948200000004,
#  606778723: 31.572336100000005,
#  606790266: 31.5772586,
#  606790312: 31.579077299999998,
#  606790327: 31.5679093,
#  606790332: 31.561173600000004,
#  606791949: 31.5819184,
#  606794887: 31.5777896,
#  606794905: 31.5748394,
#  606798516: 31.575634700000002,
#  606798520: 31.5777006,
# ...

# %%
osmid_lng_key = dict(zip(df3['osmid'],df3['lng']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lng'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-faf030f30d52> in <module>()
# ...

# %%
df3.head(1)
# Out:
#    OBJECTID highway        lat         lon      osmid
# 0         1          31.588591  120.298825  313736000

# %%
osmid_lng_key = dict(zip(df3['osmid'],df3['lon']))

# %%
osmid_lng_key
# Out:
# {313736000: 120.2988253,
#  313736002: 120.2924345,
#  313736004: 120.2968899,
#  313736019: 120.28635619999999,
#  313736073: 120.2656142,
#  313736076: 120.27938119999999,
#  313736081: 120.2925152,
#  313736097: 120.31972169999999,
#  313736102: 120.32318640000001,
#  313736149: 120.3031459,
#  313736389: 120.2995291,
#  506565871: 120.30375990000002,
#  506565876: 120.2893326,
#  544367022: 120.3018459,
#  544367024: 120.29790179999999,
#  544367025: 120.30283440000001,
#  544367031: 120.30420330000001,
#  544367033: 120.2997173,
#  544367035: 120.30483909999998,
#  544367037: 120.30197439999999,
#  544367039: 120.29778449999999,
#  606775659: 120.2896861,
#  606775671: 120.2834467,
#  606778663: 120.2975616,
#  606778723: 120.3036166,
#  606790266: 120.286705,
#  606790312: 120.27501200000002,
#  606790327: 120.2632697,
#  606790332: 120.26503400000001,
#  606791949: 120.3018106,
#  606794887: 120.32463190000001,
#  606794905: 120.31264840000001,
#  606798516: 120.2954534,
# ...

# %%
df1.head(0)
# Out:
# Empty DataFrame
# Columns: [OBJECTID, access, bridge, from_, highway, key, lanes, length, maxspeed, name, oneway, osmid, ref, to, tunnel, Shape_Length]
# Index: []

# %%
df1['from_lat'] = df1['lat']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-c01446f216c3> in <module>()
# ----> 1 df1['from_lat'] = df1['lat']
#
# ...

# %%
df1['lat']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-077f87e28ba5> in <module>()
# ----> 1 df1['lat']
#
# ...

# %%
df1.head(0)
# Out:
# Empty DataFrame
# Columns: [OBJECTID, access, bridge, from_, highway, key, lanes, length, maxspeed, name, oneway, osmid, ref, to, tunnel, Shape_Length]
# Index: []

# %%
df1[from_lat] = df1[from_]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-51ff2181b852> in <module>()
# ----> 1 df1[from_lat] = df1[from_]
#
# NameError: name 'from_' is not defined

# %%
df1['from_lat'] = df1['from_']

# %%
df1.head(2)
# Out:
#    OBJECTID access bridge       from_  highway  key lanes      length  \
# 0         1                 313736000  primary    0         81.528535
# 1         2                2530789759  primary    0        327.176053
#
#   maxspeed name  oneway      osmid ref          to tunnel  Shape_Length  \
# 0           兴源路    True  147866731      2530789764            81.605676
# 1           兴源路    True  147866731       313736000           327.562185
#
#      from_lat
# 0   313736000
# 1  2530789759

# %%
df1['from_lat'].replace(osmid_lat_key)
# Out:
# 0       31.588591
# 1       31.587089
# 2       31.592855
# 3       31.593595
# 4       31.592224
# 5       31.596547
# 6       31.589694
# 7       31.588999
# 8       31.578827
# 9       31.542980
# 10      31.542982
# 11      31.544897
# 12      31.543440
# 13      31.543440
# 14      31.543297
# 15      31.543514
# 16      31.547045
# 17      31.547560
# 18      31.566251
# 19      31.566983
# 20      31.567908
# 21      31.563596
# 22      31.566767
# 23      31.582597
# 24      31.586710
# 25      31.583610
# 26      31.582352
# 27      31.582829
# 28      31.584021
# 29      31.583460
#           ...
# 1492    31.540165
# 1493    31.553313
# 1494    31.567002
# 1495    31.567993
# 1496    31.587992
# 1497    31.573256
# 1498    31.569217
# 1499    31.582505
# 1500    31.574774
# 1501    31.584074
# 1502    31.596577
# 1503    31.590959
# 1504    31.590490
# 1505    31.585712
# 1506    31.585635
# 1507    31.591117
# 1508    31.589905
# 1509    31.585635
# 1510    31.585355
# ...

# %%
df1['from_lat']=df1['from_lat'].replace(osmid_lat_key)

# %%
df1['from_lng'] = df1['from_']

# %%
df1['from_lng']=df1['from_lng'].replace(osmid_lng_key)

# %%
df1['to_lng'] = df1['to']

# %%
df1['to_lat'] = df1['to']

# %%
df1['to_lng']=df1['to_lng'].replace(osmid_lng_key)

# %%
df1.head(2)
# Out:
#    OBJECTID access bridge       from_  highway  key lanes      length  \
# 0         1                 313736000  primary    0         81.528535
# 1         2                2530789759  primary    0        327.176053
#
#   maxspeed name  oneway      osmid ref          to tunnel  Shape_Length  \
# 0           兴源路    True  147866731      2530789764            81.605676
# 1           兴源路    True  147866731       313736000           327.562185
#
#     from_lat    from_lng      to_lng      to_lat
# 0  31.588591  120.298825  120.298110  2530789764
# 1  31.587089  120.301795  120.298825   313736000

# %%
df3[[df3['osmid']==313736000]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-f835727794f4> in <module>()
# ----> 1 df3[[df3['osmid']==313736000]]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2168             elif len(key) != len(self.index):
#    2169                 raise ValueError('Item wrong length %d instead of %d.' %
# -> 2170                                  (len(key), len(self.index)))
# ...

# %%
df3.head(2)
# Out:
#    OBJECTID highway        lat         lon      osmid
# 0         1          31.588591  120.298825  313736000
# 1         2          31.592855  120.292434  313736002

# %%
df3
# Out:
#       OBJECTID highway        lat         lon       osmid
# 0            1          31.588591  120.298825   313736000
# 1            2          31.592855  120.292434   313736002
# 2            3          31.589694  120.296890   313736004
# 3            4          31.580985  120.286356   313736019
# 4            5          31.542980  120.265614   313736073
# 5            6          31.543440  120.279381   313736076
# 6            7          31.547045  120.292515   313736081
# 7            8          31.566251  120.319722   313736097
# 8            9          31.566767  120.323186   313736102
# 9           10          31.586710  120.303146   313736149
# 10          11          31.582829  120.299529   313736389
# 11          12          31.580403  120.303760   506565871
# 12          13          31.577061  120.289333   506565876
# 13          14          31.554708  120.301846   544367022
# 14          15          31.572965  120.297902   544367024
# ...

# %%
df1.head(2)
# Out:
#    OBJECTID access bridge       from_  highway  key lanes      length  \
# 0         1                 313736000  primary    0         81.528535
# 1         2                2530789759  primary    0        327.176053
#
#   maxspeed name  oneway      osmid ref          to tunnel  Shape_Length  \
# 0           兴源路    True  147866731      2530789764            81.605676
# 1           兴源路    True  147866731       313736000           327.562185
#
#     from_lat    from_lng      to_lng      to_lat
# 0  31.588591  120.298825  120.298110  2530789764
# 1  31.587089  120.301795  120.298825   313736000

# %%
df1.to_csv('major_edges_lnglat.csv')

# %%
df1.to_csv('major_edges_lnglat.csv',index=False)

# %%
df1 = pd.read_csv('data/WX_ring/major_edges_lnglat.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4397d61b1d2c> in <module>()
# ----> 1 df1 = pd.read_csv('data/WX_ring/major_edges_lnglat.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import eviltransform as ef
df1 = pd.read_csv('data/WX_ring/major_edges_lnglat.csv')

# %%
ef
# Out:
# <module 'eviltransform' from '/Users/left/anaconda3/lib/python3.6/site-packages/eviltransform/__init__.py'>

# %%
df1.head(1)
# Out:
#    OBJECTID access bridge      from_  highway  key lanes     length maxspeed  \
# 0         1                313736000  primary    0        81.528535
#
#   name  oneway      osmid ref          to tunnel  Shape_Length   from_lat  \
# 0  兴源路    True  147866731      2530789764            81.605676  31.588591
#
#      from_lng     to_lng      to_lat
# 0  120.298825  120.29811  2530789764

# %%
df1[['from_lat','from_lng','to_lng','to_lat']]
# Out:
#        from_lat    from_lng      to_lng      to_lat
# 0     31.588591  120.298825  120.298110  2530789764
# 1     31.587089  120.301795  120.298825   313736000
# 2     31.592855  120.292434  120.291740  3053008326
# 3     31.593595  120.291227  120.292434   313736002
# 4     31.592224  120.293417  120.292434   313736002
# 5     31.596547  120.295523  120.292434   313736002
# 6     31.589694  120.296890  120.296003   842983438
# 7     31.588999  120.298110  120.296890   313736004
# 8     31.578827  120.286941  120.286356   313736019
# 9     31.542980  120.265614  120.265626   854443883
# 10    31.542982  120.265894  120.265614   313736073
# 11    31.544897  120.265530  120.265614   313736073
# 12    31.543440  120.279381  120.279312  2414152435
# 13    31.543440  120.279381  120.279236  2302243856
# 14    31.543297  120.279380  120.279381   313736076
# 15    31.543514  120.282755  120.279381   313736076
# 16    31.547045  120.292515  120.290672  2310684926
# ...

# %%
df1[['from_lat_mars','from_lng_mars','to_lng_mars','to_lat_mars']] = df1[['from_lat','from_lng','to_lng','to_lat']]

# %%
df1.head(1)
# Out:
#    OBJECTID access bridge      from_  highway  key lanes     length maxspeed  \
# 0         1                313736000  primary    0        81.528535
#
#   name     ...       tunnel Shape_Length   from_lat    from_lng     to_lng  \
# 0  兴源路     ...                 81.605676  31.588591  120.298825  120.29811
#
#        to_lat  from_lat_mars  from_lng_mars  to_lng_mars  to_lat_mars
# 0  2530789764      31.588591     120.298825    120.29811   2530789764
#
# [1 rows x 24 columns]

# %%
df1['to_lat']=df1['to_lat'].replace(osmid_lat_key)

# %%
df1.head(0)
# Out:
# Empty DataFrame
# Columns: [OBJECTID, access, bridge, from_, highway, key, lanes, length, maxspeed, name, oneway, osmid, ref, to, tunnel, Shape_Length, from_lat, from_lng, to_lng, to_lat, from_lat_mars, from_lng_mars, to_lng_mars, to_lat_mars]
# Index: []
#
# [0 rows x 24 columns]

# %%
df1.head(1)
# Out:
#    OBJECTID access bridge      from_  highway  key lanes     length maxspeed  \
# 0         1                313736000  primary    0        81.528535
#
#   name     ...       tunnel Shape_Length   from_lat    from_lng     to_lng  \
# 0  兴源路     ...                 81.605676  31.588591  120.298825  120.29811
#
#       to_lat  from_lat_mars  from_lng_mars  to_lng_mars  to_lat_mars
# 0  31.588999      31.588591     120.298825    120.29811   2530789764
#
# [1 rows x 24 columns]

# %%
df1['to_lat_mars'] = df1['to_lat']

# %%
df1.head(1)
# Out:
#    OBJECTID access bridge      from_  highway  key lanes     length maxspeed  \
# 0         1                313736000  primary    0        81.528535
#
#   name     ...       tunnel Shape_Length   from_lat    from_lng     to_lng  \
# 0  兴源路     ...                 81.605676  31.588591  120.298825  120.29811
#
#       to_lat  from_lat_mars  from_lng_mars  to_lng_mars  to_lat_mars
# 0  31.588999      31.588591     120.298825    120.29811    31.588999
#
# [1 rows x 24 columns]

# %%
ef
# Out:
# <module 'eviltransform' from '/Users/left/anaconda3/lib/python3.6/site-packages/eviltransform/__init__.py'>

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=1522, step=1)

# %%
for i in df1.index:
    from_lat = df1.loc[i]['from_lat']
    from_lng = df1.loc[i]['from_lng']
    to_lat = df1.loc[i]['to_lat']
    to_lng = df1.loc[i]['to_lng']
    df1.loc[i]['from_lat_mars'],df1.loc[i]['from_lng_mars'] = ef.wgs2gcj(from_lat,from_lng)
    df1.loc[i]['to_lat_mars'],df1.loc[i]['to_lng_mars'] = ef.wgs2gcj(to_lat,to_lng)
# Out:
# /Users/left/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/left/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-941d74039dc7> in <module>()
#       3     from_lng = df1.loc[i]['from_lng']
#       4     to_lat = df1.loc[i]['to_lat']
# ----> 5     to_lng = df1.loc[i]['to_lng']
# ...

# %%
for i in df1.index:
    from_lat = df1.iloc[i]['from_lat']
    from_lng = df1.iloc[i]['from_lng']
    to_lat = df1.iloc[i]['to_lat']
    to_lng = df1.iloc[i]['to_lng']
    df1.iloc[i]['from_lat_mars'],df1.iloc[i]['from_lng_mars'] = ef.wgs2gcj(from_lat,from_lng)
    df1.iloc[i]['to_lat_mars'],df1.iloc[i]['to_lng_mars'] = ef.wgs2gcj(to_lat,to_lng)
# Out:
# /Users/left/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/left/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df1.ix[1]

# %%
2
